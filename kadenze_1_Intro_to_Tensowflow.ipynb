# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/JacksonIsaac/kadenze-deeplearning-creative-applications/blob/master/kadenze_1_Intro_to_Tensowflow.ipynb)

# %%
# %pylab
# Out:
# Using matplotlib backend: TkAgg
# Populating the interactive namespace from numpy and matplotlib

# %%
# %matplotlib inline

# %%
plt.style.use('ggplot')

# %%
# !git clone https://github.com/pkmital/CADL.git
# Out:
# Cloning into 'CADL'...
# remote: Counting objects: 2074, done.
# remote: Total 2074 (delta 0), reused 0 (delta 0), pack-reused 2074
# Receiving objects: 100% (2074/2074), 322.71 MiB | 38.16 MiB/s, done.
# Resolving deltas: 100% (1032/1032), done.

# %%
# !mv CADL/session-1/* .

# %%
# !ls
# Out:
# CADL	 lecture-1.ipynb  README.md    session-1.ipynb
# datalab  libs		  sample_data  tests

# %%
from libs import utils

# %%
??utils

# %%
files = utils.get_celeb_files()

# %%
files

# %%
img = plt.imread(files[50])

# %%
img

# %%
shape(img)
# Out:
# (218, 178, 3)

# %%
plt.imshow(img)

# %%
plt.imshow(img[:,:,0], cmap='gray')

# %%
plt.imshow(img[:,:,1], cmap='gray')

# %%
plt.imshow(img[:,:,2], cmap='gray')

# %%
imgs = utils.get_celeb_imgs()

# %% [markdown]
# ### Batch \* Height \* Width \* Channel

# %%
shape(imgs)
# Out:
# (100, 218, 178, 3)

# %%
plt.imshow(imgs[0])

# %%
plt.imshow(imgs[1])

# %%
plt.imshow(imgs[2])

# %%
data = np.array(imgs)

# %%
mean_img = np.mean(data, axis=0)

# %%
plt.imshow(mean_img)

# %%
plt.imshow(mean_img.astype(np.uint8))

# %%
plt.imshow(np.mean(data, axis=1).astype(np.uint8))

# %%
std_img = np.std(data, axis=0)

# %%
plt.imshow(std_img.astype(np.uint8))
